# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("dataset/heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  ...  exang  oldpeak  slope  ca  thal  num
# 0   69    0   0       125   245    0  ...      0      3.7      0   0     3    1
# 1   42    0   0       161   221    1  ...      1      5.0      0   1     7    1
# 2   56    1   2       109   230    1  ...      1      0.6      1   4     6    1
# 3   31    1   0       138   160    1  ...      0      4.4      0   1     6    0
# 4   34    0   0       138   262    1  ...      0      2.3      0   2     7    1
#
# [5 rows x 14 columns]

# %%
x = df.drop("num", axis = 1)
y = (df["num"]>0).astype(int)

# %%
x = StandardScaler().fit_transform(x)

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size = 0.3, random_state = 42
)

# %%
m1 = KNeighborsClassifier(
    n_neighbors=5)
m2 = KNeighborsClassifier(
    n_neighbors=5, weights="distance")

m1.fit(x_train, y_train)
m2.fit(x_train, y_train)
p1 = m1.predict(x_test)
p2 = m2.predict(x_test)

print("Standard KNN: ", accuracy_score(y_test, p1))
print("Weighted KNN: ", accuracy_score(y_test, p2))
# Out:
# Standard KNN:  0.7933333333333333
# Weighted KNN:  0.7933333333333333
