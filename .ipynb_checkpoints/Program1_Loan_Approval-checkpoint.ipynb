# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv("dataset/loan_approval.csv")
df.head()
# Out:
#    person_age  person_income  ...  credit_score  loan_status
# 0          61          47184  ...           442            1
# 1          27         160964  ...           330            1
# 2          26          75314  ...           503            1
# 3          62         160853  ...           584            0
# 4          21          59853  ...           520            1
#
# [5 rows x 8 columns]

# %%
df.describe()
# Out:
#        person_age  person_income  ...  credit_score  loan_status
# count   500.00000     500.000000  ...    500.000000   500.000000
# mean     43.44600   98643.940000  ...    592.094000     0.468000
# std      12.97211   46605.081259  ...    153.984465     0.499475
# min      21.00000   19166.000000  ...    300.000000     0.000000
# 25%      31.75000   55661.750000  ...    456.750000     0.000000
# 50%      44.00000  100870.500000  ...    609.500000     0.000000
# 75%      55.00000  136904.750000  ...    724.250000     1.000000
# max      65.00000  179656.000000  ...    850.000000     1.000000
#
# [8 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   person_age           500 non-null    int64
#  1   person_income        500 non-null    int64
#  2   person_emp_length    500 non-null    int64
#  3   loan_amnt            500 non-null    int64
#  4   loan_int_rate        500 non-null    float64
#  5   loan_percent_income  500 non-null    float64
#  6   credit_score         500 non-null    int64
#  7   loan_status          500 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 31.4 KB

# %%
sns.histplot(df['person_age'])
plt.show()

# %%
sns.scatterplot(x='person_age', y='person_income', data=df)
plt.show()

# %%
sns.countplot(x='loan_status', data=df)
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %%
x = df.drop(columns=['loan_status'])
y = df['loan_status']

# %%
print(type(y_train))
print(y_train.shape)
print(y_train.head())
# Out:
# <class 'pandas.DataFrame'>
# (100, 7)
#      person_age  person_income  ...  loan_percent_income  credit_score
# 361          52          66840  ...                 0.10           409
# 73           37          29635  ...                 0.07           501
# 374          55          75255  ...                 0.17           840
# 155          35          47743  ...                 0.36           457
# 104          33          23342  ...                 0.94           784
#
# [5 rows x 7 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size = 0.2, random_state = 42
)

# %%
model1 = DecisionTreeClassifier()
model1.fit(x_train, y_train)
pred1 = model1.predict(x_test)
print(f"Decision Tree Accuracy: {accuracy_score(y_test, pred1)}")
# Out:
# Decision Tree Accuracy: 0.97

# %%
model2 = GaussianNB()
model2.fit(x_train, y_train)
pred2 = model2.predict(x_test)
print(f"Navie Bayes Accuracy: {accuracy_score(y_test, pred2)}")
# Out:
# Navie Bayes Accuracy: 0.89
