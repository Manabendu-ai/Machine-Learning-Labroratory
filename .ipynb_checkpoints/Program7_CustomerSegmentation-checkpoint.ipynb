# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dataset/customers.csv")

df.head()
# Out:
#    Customer_ID Gender  Age       City  Avg_Purchase_Value  Purchase_Frequency
# 0            1   Male   19      Delhi               11012                  19
# 1            2   Male   61     Jaipur                 678                   5
# 2            3   Male   19  Bengaluru                4291                   8
# 3            4   Male   53  Hyderabad               18731                  29
# 4            5   Male   46      Kochi                4778                   5

# %%
x = df[["Avg_Purchase_Value","Purchase_Frequency"]]

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
df["cluster"] = kmeans.fit_predict(x_scaled)

# %%
df.head()
# Out:
#    Customer_ID Gender  Age       City  Avg_Purchase_Value  Purchase_Frequency  \
# 0            1   Male   19      Delhi               11012                  19
# 1            2   Male   61     Jaipur                 678                   5
# 2            3   Male   19  Bengaluru                4291                   8
# 3            4   Male   53  Hyderabad               18731                  29
# 4            5   Male   46      Kochi                4778                   5
#
#    cluster
# 0        1
# 1        0
# 2        0
# 3        2
# 4        0

# %%
sns.scatterplot(x = x_scaled[:,0],
                y = x_scaled[:,1],
                hue = df["cluster"],
               )
plt.title("Customer Segmentation using K-Means")
plt.show()
